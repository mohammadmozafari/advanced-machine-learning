# %% [markdown]
# # *Attention*
#
# In order to be able to run this notebook without problems, one must do the following first:
# - Add a shortcut of [this](https://drive.google.com/drive/folders/1l-74Qd42waVghTfSsJAPJIMXeg0f77XK?usp=sharing) drive folder to your own drive.
# - Mount on your drive.
# - Set the *drive_folder* variable to point to the path of the shared folder on your drive.

# %%
drive_folder = './drive/MyDrive/Shortcuts/AML_HW1/'
# !ls './drive/MyDrive/Shortcuts/AML_HW1/'
# Out:
# AML_HW1.pdf  AML_HW1.zip  Practical

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp './drive/MyDrive/Shortcuts/AML_HW1/AML_HW1.zip' './'
# !unzip AML_HW1.zip

# %% [markdown]
# # **Imports**

# %%
import os
import glob
import time
import torch
import torchvision
import numpy as np
import torch.nn as nn
from PIL import Image
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # **Parameters**

# %%
data_path = 'AML_HW1/Practical/Q4/tiny-image-subset/'

BATCH_SIZE = 128
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda:0

# %% [markdown]
# # **General Utilities**

# %%
def conv_block(in_channels, out_channels):
    '''
    returns a block conv-bn-relu-pool
    '''
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(),
        nn.MaxPool2d(2)
    )
    
class ProtoNetBack(nn.Module):
    def __init__(self, input_channels = 1):
        super(ProtoNetBack, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(input_channels, 64, 1),
            conv_block(64, 128),
            conv_block(128, 128),
            conv_block(128, 128),
            conv_block(128, 128),
        )

    def get_embedding_size(self, input_size = (1,28,28)):
        device = next(self.parameters()).device
        x = torch.rand([2,*input_size]).to(device)
        with torch.no_grad():
            output = self.forward(x)
            emb_size = output.shape[-1]
        
        del x,output
        torch.cuda.empty_cache()

        return emb_size

    def forward(self, x):
        return self.layers (x).reshape ([x.shape[0] , -1])

# %%
class Trainer():

    def __init__(self, name, net, optimizer, criterion, epochs, trainloader,
                 valloader, log_every_iter=100, eval_every_epoch=1, save_every_iter=500,
                 save_path='./', device=None):
        
        self.epochs = epochs
        self.trainloader = trainloader
        self.valloader = valloader
        self.net = net
        self.optimizer = optimizer
        self.criterion = criterion
        self.log_every_iter = log_every_iter
        self.eval_every_epoch = eval_every_epoch
        self.device = device
        self.save_path = save_path
        self.save_every_iter = save_every_iter
        self.name = name
    
    def train(self):
        print('Number of iterations in each epoch: {}'.format(len(self.trainloader)))
        print('Number of validation iterations: {}'.format(len(self.valloader)))
        print('Training started ...')
        
        history = {
            'train_loss': [],
            'train_acc': [],
            'val_acc': []
        }
        epoch_train_loss = 0.0
        epoch_train_acc = 0.0
        epoch_count = 0.0
        
        for epoch in range(self.epochs):
            
            running_loss = 0.0
            running_lp_fraction = 0.0
            running_accuracy = 0.0
            tick = time.time()
            t = time.time()

            for i, data in enumerate(self.trainloader, 0):
                
                overhead_duration = time.time() - t
                t = time.time()

                inputs, labels = data
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.net(inputs)
                loss = self.criterion(outputs, labels)
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
                preds = torch.argmax(outputs, axis=1)
                acc = ((preds == labels) * 1.0).mean()

                running_loss += loss.item()
                running_accuracy += acc.item()
                epoch_train_loss += loss.item() * inputs.shape[0]
                epoch_train_acc += acc.item() * inputs.shape[0]
                epoch_count += inputs.shape[0]

                processing_duration = time.time() - t
                t = time.time()
                running_lp_fraction += overhead_duration / processing_duration

                if i % self.log_every_iter == self.log_every_iter - 1:
                    tock = time.time()
                    print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / self.log_every_iter:.3f}, \
                            accuracy = {running_accuracy / self.log_every_iter:.4f}')
                    tick = time.time()
                    running_loss = 0.0
                    running_lp_fraction = 0.0
                    running_accuracy = 0.0
                
                # if i % self.save_every_iter == self.save_every_iter - 1:
                #     self.save_model(epoch)
                #     print('Training saved')

            if epoch % self.eval_every_epoch == self.eval_every_epoch - 1:
                epoch_val_acc = self.evaluate()
                self.net.train()
            
            history['train_loss'].append(epoch_train_loss / epoch_count)
            history['train_acc'].append(epoch_train_acc / epoch_count)
            history['val_acc'].append(epoch_val_acc)
            epoch_train_loss = 0.0
            epoch_train_acc = 0.0
            epoch_count = 0.0

        self.save_model(self.epochs, False)
        print('Finished Training')
        return history

    def evaluate(self):
        print('Evaluating on validation set ...')
        sum_acc, sum_loss = 0.0, 0.0
        total_data = 0
        self.net.eval()
        for i, data in enumerate(self.valloader, 0):
            inputs, labels = data
            inputs = inputs.to(self.device)
            labels = labels.to(self.device)
            outputs = self.net(inputs)
            total_data += outputs.shape[0]
            preds = torch.argmax(outputs, axis=1)
            acc = ((preds == labels) * 1.0).mean()
            sum_acc += acc.item() * preds.shape[0]

        epoch_acc = sum_acc / total_data
        print('{}: {}'.format('accuracy', epoch_acc)) 
        print('-------------------------------')
        return epoch_acc

    def save_model(self, epoch, checkpoint=True):
        if checkpoint:
            torch.save({
                'model_state_dict': self.net.state_dict(),
                'optimizer_state_dict': self.optimizer.state_dict(),
            }, os.path.join(self.save_path, '%04d.pth' % (epoch + 1)))
        else:
            torch.save({
                'model_state_dict': self.net.state_dict()
            }, os.path.join(self.save_path, '{}.pth'.format(self.name)))

# %% [markdown]
# # **Part A**

# %% [markdown]
# ## Model Definition

# %%
class CustomNet(nn.Module):
    def __init__(self, input_channels=1):
        super(CustomNet, self).__init__()
        self.pn_back = ProtoNetBack(input_channels=input_channels)
        self.fc1 = nn.Linear(512, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pn_back(x)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        out = self.fc3(x)
        return out

# %% [markdown]
# ## Train on CIFAR-10

# %%
from torchvision.transforms.transforms import RandomHorizontalFlip
transform = transforms.Compose(
    [
     transforms.ToTensor(),
     transforms.Resize((32, 32)),
     transforms.RandomCrop(25),
     transforms.Resize((32, 32)),
     transforms.RandomHorizontalFlip(0.5),
     transforms.ColorJitter(brightness=0.5, hue=0.3),
    #  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
     ])

trainset = torchvision.datasets.CIFAR10(root='./', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
net = CustomNet(input_channels=3).to(DEVICE)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)
criterion = torch.nn.CrossEntropyLoss()

tr = Trainer('4a', net, optimizer, criterion, 20, trainloader, testloader,
             log_every_iter=30, eval_every_epoch=1, save_every_iter=190,
             device=DEVICE)
history = tr.train()
# Out:
# Number of iterations in each epoch: 391
# Number of validation iterations: 79
# Training started ...
# [1,    30] loss: 2.136,                             accuracy = 0.1948
# [1,    60] loss: 1.948,                             accuracy = 0.2745
# [1,    90] loss: 1.870,                             accuracy = 0.3000
# [1,   120] loss: 1.783,                             accuracy = 0.3419
# [1,   150] loss: 1.731,                             accuracy = 0.3677
# [1,   180] loss: 1.630,                             accuracy = 0.3995
# [1,   210] loss: 1.622,                             accuracy = 0.4047
# [1,   240] loss: 1.600,                             accuracy = 0.4232
# [1,   270] loss: 1.507,                             accuracy = 0.4568
# [1,   300] loss: 1.488,                             accuracy = 0.4602
# [1,   330] loss: 1.483,                             accuracy = 0.4727
# [1,   360] loss: 1.412,                             accuracy = 0.4885
# [1,   390] loss: 1.351,                             accuracy = 0.5188
# Evaluating on validation set ...
# accuracy: 0.4602
# -------------------------------
# [2,    30] loss: 1.370,                             accuracy = 0.5036
# [2,    60] loss: 1.349,                             accuracy = 0.5073
# [2,    90] loss: 1.315,                             accuracy = 0.5211
# [2,   120] loss: 1.284,                             accuracy = 0.5510
# [2,   150] loss: 1.274,                             accuracy = 0.5393
# [2,   180] loss: 1.232,                             accuracy = 0.5552
# [2,   210] loss: 1.219,                             accuracy = 0.5602
# [2,   240] loss: 1.256,                             accuracy = 0.5510
# [2,   270] loss: 1.204,                             accuracy = 0.5784
# [2,   300] loss: 1.166,                             accuracy = 0.5878
# [2,   330] loss: 1.168,                             accuracy = 0.5857
# [2,   360] loss: 1.164,                             accuracy = 0.5854
# [2,   390] loss: 1.198,                             accuracy = 0.5711
# Evaluating on validation set ...
# accuracy: 0.5665
# -------------------------------
# [3,    30] loss: 1.107,                             accuracy = 0.6094
# [3,    60] loss: 1.164,                             accuracy = 0.5875
# [3,    90] loss: 1.101,                             accuracy = 0.6018
# [3,   120] loss: 1.113,                             accuracy = 0.6057
# [3,   150] loss: 1.077,                             accuracy = 0.6141
# [3,   180] loss: 1.088,                             accuracy = 0.6229
# [3,   210] loss: 1.111,                             accuracy = 0.6068
# [3,   240] loss: 1.047,                             accuracy = 0.6346
# [3,   270] loss: 1.065,                             accuracy = 0.6190
# [3,   300] loss: 1.032,                             accuracy = 0.6375
# [3,   330] loss: 1.045,                             accuracy = 0.6211
# [3,   360] loss: 1.040,                             accuracy = 0.6312
# [3,   390] loss: 1.051,                             accuracy = 0.6260
# Evaluating on validation set ...
# accuracy: 0.5891
# -------------------------------
# [4,    30] loss: 1.030,                             accuracy = 0.6383
# [4,    60] loss: 0.970,                             accuracy = 0.6557
# [4,    90] loss: 0.988,                             accuracy = 0.6583
# [4,   120] loss: 1.005,                             accuracy = 0.6474
# [4,   150] loss: 0.976,                             accuracy = 0.6638
# [4,   180] loss: 0.990,                             accuracy = 0.6495
# [4,   210] loss: 0.980,                             accuracy = 0.6536
# [4,   240] loss: 0.981,                             accuracy = 0.6578
# [4,   270] loss: 0.975,                             accuracy = 0.6531
# [4,   300] loss: 0.957,                             accuracy = 0.6552
# [4,   330] loss: 0.977,                             accuracy = 0.6659
# [4,   360] loss: 0.963,                             accuracy = 0.6628
# [4,   390] loss: 0.957,                             accuracy = 0.6586
# Evaluating on validation set ...
# accuracy: 0.5917
# -------------------------------
# [5,    30] loss: 0.947,                             accuracy = 0.6685
# [5,    60] loss: 0.941,                             accuracy = 0.6724
# [5,    90] loss: 0.925,                             accuracy = 0.6826
# [5,   120] loss: 0.923,                             accuracy = 0.6747
# [5,   150] loss: 0.940,                             accuracy = 0.6693
# [5,   180] loss: 0.895,                             accuracy = 0.6849
# [5,   210] loss: 0.930,                             accuracy = 0.6706
# [5,   240] loss: 0.896,                             accuracy = 0.6833
# [5,   270] loss: 0.904,                             accuracy = 0.6823
# [5,   300] loss: 0.911,                             accuracy = 0.6909
# [5,   330] loss: 0.926,                             accuracy = 0.6792
# [5,   360] loss: 0.868,                             accuracy = 0.6966
# [5,   390] loss: 0.928,                             accuracy = 0.6799
# Evaluating on validation set ...
# accuracy: 0.6387
# -------------------------------
# [6,    30] loss: 0.898,                             accuracy = 0.6831
# [6,    60] loss: 0.859,                             accuracy = 0.7016
# [6,    90] loss: 0.807,                             accuracy = 0.7227
# [6,   120] loss: 0.875,                             accuracy = 0.6951
# [6,   150] loss: 0.893,                             accuracy = 0.6846
# [6,   180] loss: 0.870,                             accuracy = 0.6966
# [6,   210] loss: 0.867,                             accuracy = 0.6964
# [6,   240] loss: 0.871,                             accuracy = 0.6924
# [6,   270] loss: 0.876,                             accuracy = 0.6937
# [6,   300] loss: 0.859,                             accuracy = 0.7010
# [6,   330] loss: 0.858,                             accuracy = 0.7003
# [6,   360] loss: 0.874,                             accuracy = 0.6958
# [6,   390] loss: 0.850,                             accuracy = 0.7096
# Evaluating on validation set ...
# accuracy: 0.657
# -------------------------------
# [7,    30] loss: 0.831,                             accuracy = 0.7057
# [7,    60] loss: 0.869,                             accuracy = 0.6990
# [7,    90] loss: 0.794,                             accuracy = 0.7253
# [7,   120] loss: 0.847,                             accuracy = 0.7018
# [7,   150] loss: 0.815,                             accuracy = 0.7214
# [7,   180] loss: 0.829,                             accuracy = 0.7125
# [7,   210] loss: 0.828,                             accuracy = 0.7122
# [7,   240] loss: 0.860,                             accuracy = 0.7091
# [7,   270] loss: 0.803,                             accuracy = 0.7268
# [7,   300] loss: 0.811,                             accuracy = 0.7214
# [7,   330] loss: 0.833,                             accuracy = 0.7156
# [7,   360] loss: 0.812,                             accuracy = 0.7128
# [7,   390] loss: 0.812,                             accuracy = 0.7203
# Evaluating on validation set ...
# accuracy: 0.6915
# -------------------------------
# [8,    30] loss: 0.781,                             accuracy = 0.7216
# [8,    60] loss: 0.788,                             accuracy = 0.7240
# [8,    90] loss: 0.809,                             accuracy = 0.7156
# [8,   120] loss: 0.815,                             accuracy = 0.7128
# [8,   150] loss: 0.772,                             accuracy = 0.7240
# [8,   180] loss: 0.795,                             accuracy = 0.7229
# [8,   210] loss: 0.791,                             accuracy = 0.7247
# [8,   240] loss: 0.813,                             accuracy = 0.7159
# [8,   270] loss: 0.780,                             accuracy = 0.7318
# [8,   300] loss: 0.814,                             accuracy = 0.7143
# [8,   330] loss: 0.769,                             accuracy = 0.7255
# [8,   360] loss: 0.770,                             accuracy = 0.7289
# [8,   390] loss: 0.772,                             accuracy = 0.7310
# Evaluating on validation set ...
# accuracy: 0.6846
# -------------------------------
# [9,    30] loss: 0.755,                             accuracy = 0.7435
# [9,    60] loss: 0.760,                             accuracy = 0.7414
# [9,    90] loss: 0.761,                             accuracy = 0.7333
# [9,   120] loss: 0.805,                             accuracy = 0.7169
# [9,   150] loss: 0.751,                             accuracy = 0.7328
# [9,   180] loss: 0.813,                             accuracy = 0.7219
# [9,   210] loss: 0.756,                             accuracy = 0.7307
# [9,   240] loss: 0.730,                             accuracy = 0.7497
# [9,   270] loss: 0.750,                             accuracy = 0.7346
# [9,   300] loss: 0.752,                             accuracy = 0.7461
# [9,   330] loss: 0.749,                             accuracy = 0.7393
# [9,   360] loss: 0.746,                             accuracy = 0.7365
# [9,   390] loss: 0.780,                             accuracy = 0.7315
# Evaluating on validation set ...
# accuracy: 0.7171
# -------------------------------
# [10,    30] loss: 0.713,                             accuracy = 0.7505
# [10,    60] loss: 0.751,                             accuracy = 0.7375
# [10,    90] loss: 0.770,                             accuracy = 0.7352
# [10,   120] loss: 0.734,                             accuracy = 0.7453
# [10,   150] loss: 0.701,                             accuracy = 0.7560
# [10,   180] loss: 0.728,                             accuracy = 0.7453
# [10,   210] loss: 0.765,                             accuracy = 0.7253
# [10,   240] loss: 0.736,                             accuracy = 0.7492
# [10,   270] loss: 0.743,                             accuracy = 0.7424
# [10,   300] loss: 0.735,                             accuracy = 0.7479
# [10,   330] loss: 0.732,                             accuracy = 0.7464
# [10,   360] loss: 0.739,                             accuracy = 0.7419
# [10,   390] loss: 0.768,                             accuracy = 0.7286
# Evaluating on validation set ...
# accuracy: 0.7103
# -------------------------------
# [11,    30] loss: 0.689,                             accuracy = 0.7594
# [11,    60] loss: 0.705,                             accuracy = 0.7625
# [11,    90] loss: 0.707,                             accuracy = 0.7521
# [11,   120] loss: 0.703,                             accuracy = 0.7586
# [11,   150] loss: 0.734,                             accuracy = 0.7448
# [11,   180] loss: 0.711,                             accuracy = 0.7565
# [11,   210] loss: 0.675,                             accuracy = 0.7625
# [11,   240] loss: 0.718,                             accuracy = 0.7495
# [11,   270] loss: 0.710,                             accuracy = 0.7466
# [11,   300] loss: 0.758,                             accuracy = 0.7362
# [11,   330] loss: 0.741,                             accuracy = 0.7492
# [11,   360] loss: 0.687,                             accuracy = 0.7625
# [11,   390] loss: 0.698,                             accuracy = 0.7594
# Evaluating on validation set ...
# accuracy: 0.7107
# -------------------------------
# [12,    30] loss: 0.663,                             accuracy = 0.7794
# [12,    60] loss: 0.680,                             accuracy = 0.7628
# [12,    90] loss: 0.709,                             accuracy = 0.7495
# [12,   120] loss: 0.703,                             accuracy = 0.7529
# [12,   150] loss: 0.707,                             accuracy = 0.7570
# [12,   180] loss: 0.708,                             accuracy = 0.7526
# [12,   210] loss: 0.674,                             accuracy = 0.7648
# [12,   240] loss: 0.703,                             accuracy = 0.7542
# [12,   270] loss: 0.719,                             accuracy = 0.7495
# [12,   300] loss: 0.682,                             accuracy = 0.7542
# [12,   330] loss: 0.691,                             accuracy = 0.7568
# [12,   360] loss: 0.694,                             accuracy = 0.7576
# [12,   390] loss: 0.696,                             accuracy = 0.7602
# Evaluating on validation set ...
# accuracy: 0.7481
# -------------------------------
# [13,    30] loss: 0.679,                             accuracy = 0.7552
# [13,    60] loss: 0.685,                             accuracy = 0.7544
# [13,    90] loss: 0.644,                             accuracy = 0.7760
# [13,   120] loss: 0.670,                             accuracy = 0.7609
# [13,   150] loss: 0.657,                             accuracy = 0.7734
# [13,   180] loss: 0.661,                             accuracy = 0.7766
# [13,   210] loss: 0.657,                             accuracy = 0.7669
# [13,   240] loss: 0.689,                             accuracy = 0.7599
# [13,   270] loss: 0.671,                             accuracy = 0.7667
# [13,   300] loss: 0.713,                             accuracy = 0.7510
# [13,   330] loss: 0.692,                             accuracy = 0.7596
# [13,   360] loss: 0.672,                             accuracy = 0.7693
# [13,   390] loss: 0.672,                             accuracy = 0.7638
# Evaluating on validation set ...
# accuracy: 0.7076
# -------------------------------
# [14,    30] loss: 0.635,                             accuracy = 0.7805
# [14,    60] loss: 0.641,                             accuracy = 0.7766
# [14,    90] loss: 0.653,                             accuracy = 0.7711
# [14,   120] loss: 0.648,                             accuracy = 0.7706
# [14,   150] loss: 0.671,                             accuracy = 0.7706
# [14,   180] loss: 0.671,                             accuracy = 0.7635
# [14,   210] loss: 0.647,                             accuracy = 0.7703
# [14,   240] loss: 0.651,                             accuracy = 0.7763
# [14,   270] loss: 0.678,                             accuracy = 0.7651
# [14,   300] loss: 0.653,                             accuracy = 0.7708
# [14,   330] loss: 0.658,                             accuracy = 0.7768
# [14,   360] loss: 0.664,                             accuracy = 0.7714
# [14,   390] loss: 0.654,                             accuracy = 0.7698
# Evaluating on validation set ...
# accuracy: 0.7611
# -------------------------------
# [15,    30] loss: 0.625,                             accuracy = 0.7826
# [15,    60] loss: 0.651,                             accuracy = 0.7729
# [15,    90] loss: 0.655,                             accuracy = 0.7740
# [15,   120] loss: 0.638,                             accuracy = 0.7826
# [15,   150] loss: 0.665,                             accuracy = 0.7674
# [15,   180] loss: 0.638,                             accuracy = 0.7732
# [15,   210] loss: 0.674,                             accuracy = 0.7633
# [15,   240] loss: 0.637,                             accuracy = 0.7734
# [15,   270] loss: 0.625,                             accuracy = 0.7805
# [15,   300] loss: 0.620,                             accuracy = 0.7846
# [15,   330] loss: 0.646,                             accuracy = 0.7784
# [15,   360] loss: 0.652,                             accuracy = 0.7695
# [15,   390] loss: 0.633,                             accuracy = 0.7729
# Evaluating on validation set ...
# accuracy: 0.745
# -------------------------------
# [16,    30] loss: 0.599,                             accuracy = 0.7919
# [16,    60] loss: 0.649,                             accuracy = 0.7802
# [16,    90] loss: 0.636,                             accuracy = 0.7750
# [16,   120] loss: 0.635,                             accuracy = 0.7763
# [16,   150] loss: 0.610,                             accuracy = 0.7888
# [16,   180] loss: 0.629,                             accuracy = 0.7810
# [16,   210] loss: 0.622,                             accuracy = 0.7818
# [16,   240] loss: 0.613,                             accuracy = 0.7893
# [16,   270] loss: 0.620,                             accuracy = 0.7862
# [16,   300] loss: 0.615,                             accuracy = 0.7865
# [16,   330] loss: 0.639,                             accuracy = 0.7703
# [16,   360] loss: 0.655,                             accuracy = 0.7794
# [16,   390] loss: 0.624,                             accuracy = 0.7818
# Evaluating on validation set ...
# accuracy: 0.7573
# -------------------------------
# [17,    30] loss: 0.611,                             accuracy = 0.7857
# [17,    60] loss: 0.610,                             accuracy = 0.7818
# [17,    90] loss: 0.603,                             accuracy = 0.7898
# [17,   120] loss: 0.634,                             accuracy = 0.7779
# [17,   150] loss: 0.612,                             accuracy = 0.7836
# [17,   180] loss: 0.637,                             accuracy = 0.7792
# [17,   210] loss: 0.597,                             accuracy = 0.7896
# [17,   240] loss: 0.608,                             accuracy = 0.7893
# [17,   270] loss: 0.610,                             accuracy = 0.7839
# [17,   300] loss: 0.621,                             accuracy = 0.7875
# [17,   330] loss: 0.596,                             accuracy = 0.7982
# [17,   360] loss: 0.607,                             accuracy = 0.7930
# [17,   390] loss: 0.594,                             accuracy = 0.7901
# Evaluating on validation set ...
# accuracy: 0.7486
# -------------------------------
# [18,    30] loss: 0.604,                             accuracy = 0.7927
# [18,    60] loss: 0.579,                             accuracy = 0.7992
# [18,    90] loss: 0.575,                             accuracy = 0.7961
# [18,   120] loss: 0.600,                             accuracy = 0.7961
# [18,   150] loss: 0.592,                             accuracy = 0.7984
# [18,   180] loss: 0.625,                             accuracy = 0.7841
# [18,   210] loss: 0.597,                             accuracy = 0.7940
# [18,   240] loss: 0.579,                             accuracy = 0.7927
# [18,   270] loss: 0.593,                             accuracy = 0.7917
# [18,   300] loss: 0.617,                             accuracy = 0.7867
# [18,   330] loss: 0.598,                             accuracy = 0.7854
# [18,   360] loss: 0.601,                             accuracy = 0.7862
# [18,   390] loss: 0.577,                             accuracy = 0.7969
# Evaluating on validation set ...
# accuracy: 0.7602
# -------------------------------
# [19,    30] loss: 0.575,                             accuracy = 0.8016
# [19,    60] loss: 0.534,                             accuracy = 0.8156
# [19,    90] loss: 0.620,                             accuracy = 0.7836
# [19,   120] loss: 0.617,                             accuracy = 0.7818
# [19,   150] loss: 0.595,                             accuracy = 0.7937
# [19,   180] loss: 0.577,                             accuracy = 0.8008
# [19,   210] loss: 0.586,                             accuracy = 0.7977
# [19,   240] loss: 0.575,                             accuracy = 0.7937
# [19,   270] loss: 0.592,                             accuracy = 0.7945
# [19,   300] loss: 0.595,                             accuracy = 0.7958
# [19,   330] loss: 0.606,                             accuracy = 0.7896
# [19,   360] loss: 0.595,                             accuracy = 0.7987
# [19,   390] loss: 0.584,                             accuracy = 0.7958
# Evaluating on validation set ...
# accuracy: 0.7542
# -------------------------------
# [20,    30] loss: 0.553,                             accuracy = 0.8104
# [20,    60] loss: 0.563,                             accuracy = 0.8044
# [20,    90] loss: 0.557,                             accuracy = 0.8068
# [20,   120] loss: 0.602,                             accuracy = 0.7906
# [20,   150] loss: 0.603,                             accuracy = 0.7922
# [20,   180] loss: 0.563,                             accuracy = 0.8047
# [20,   210] loss: 0.592,                             accuracy = 0.7977
# [20,   240] loss: 0.577,                             accuracy = 0.7992
# [20,   270] loss: 0.564,                             accuracy = 0.8065
# [20,   300] loss: 0.582,                             accuracy = 0.7958
# [20,   330] loss: 0.564,                             accuracy = 0.8029
# [20,   360] loss: 0.609,                             accuracy = 0.7839
# [20,   390] loss: 0.585,                             accuracy = 0.8005
# Evaluating on validation set ...
# accuracy: 0.7518
# -------------------------------
# Finished Training

# %%
# plots

xaxis = list(range(len(history['train_loss'])))
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
ax1.plot(xaxis, history['train_loss'])
ax1.set_title('Train Loss')
ax1.set_xlabel('Epoch Number')
ax1.set_ylabel('Loss')
ax2.plot(xaxis, history['train_acc'], label='Train')
ax2.plot(xaxis, history['val_acc'], label='Validation')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch Number')
ax2.set_ylabel('Accuracy')
ax2.legend()

# %% [markdown]
# # **Part B**

# %% [markdown]
# ## Hyperparameters

# %%
BATCH_SIZE = 128

# %% [markdown]
# ## Tiny Image Dataset

# %%
class TinyImageDataset(Dataset):

    def __init__(self, path, transform=None):
        self.classes = sorted(glob.glob('{}/*'.format(path)))
        self.num_images = len(glob.glob('{}/*/*'.format(path), recursive=True))
        self.x = []
        self.y = []
        for i, c in enumerate(self.classes):
            image_paths = glob.glob('{}/*'.format(c))
            for image_path in image_paths:
                img = self.pil_loader(image_path)
                self.x.append(img)
                self.y.append(i)
        self.transform = transform

    def pil_loader(self, path):
        with open(path, 'rb') as f:
            img = Image.open(f)
            return img.convert('RGB')

    def __len__(self):
        return self.num_images

    def __getitem__(self, idx):
        return self.transform(self.x[idx]), self.y[idx]

transform = transforms.Compose(
    [
     transforms.ToTensor(),
     transforms.Resize((32, 32)),
    #  transforms.RandomCrop(25),
    #  transforms.Resize((32, 32)),
    #  transforms.RandomHorizontalFlip(0.5),
    #  transforms.ColorJitter(brightness=0.5, hue=0.3),
    #  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

trainset = TinyImageDataset(data_path + 'train', transform=transform)
valset = TinyImageDataset(data_path + 'val', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=1)
valloader = torch.utils.data.DataLoader(valset, batch_size=BATCH_SIZE, shuffle=False, num_workers=1)

# %%
img = trainset[100][0].numpy()
plt.imshow(img.transpose((1, 2, 0)))

# %% [markdown]
# ## Part B.1 (Training from scratch)

# %%
net = CustomNet(input_channels=3).to(DEVICE)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)
criterion = torch.nn.CrossEntropyLoss()

tr = Trainer('4b1', net, optimizer, criterion, 20, trainloader, valloader,
             log_every_iter=15, eval_every_epoch=1, device=DEVICE)
history = tr.train()
# Out:
# Number of iterations in each epoch: 40
# Number of validation iterations: 4
# Training started ...
# [1,    15] loss: 2.089,                             accuracy = 0.2448
# [1,    30] loss: 1.709,                             accuracy = 0.3990
# Evaluating on validation set ...
# accuracy: 0.27199999904632566
# -------------------------------
# [2,    15] loss: 1.646,                             accuracy = 0.4198
# [2,    30] loss: 1.506,                             accuracy = 0.4854
# Evaluating on validation set ...
# accuracy: 0.4059999983310699
# -------------------------------
# [3,    15] loss: 1.425,                             accuracy = 0.5000
# [3,    30] loss: 1.367,                             accuracy = 0.5312
# Evaluating on validation set ...
# accuracy: 0.47200000047683716
# -------------------------------
# [4,    15] loss: 1.320,                             accuracy = 0.5484
# [4,    30] loss: 1.241,                             accuracy = 0.5672
# Evaluating on validation set ...
# accuracy: 0.5079999966621399
# -------------------------------
# [5,    15] loss: 1.258,                             accuracy = 0.5594
# [5,    30] loss: 1.198,                             accuracy = 0.6000
# Evaluating on validation set ...
# accuracy: 0.35200000286102295
# -------------------------------
# [6,    15] loss: 1.171,                             accuracy = 0.5917
# [6,    30] loss: 1.077,                             accuracy = 0.6234
# Evaluating on validation set ...
# accuracy: 0.4160000057220459
# -------------------------------
# [7,    15] loss: 1.063,                             accuracy = 0.6297
# [7,    30] loss: 0.985,                             accuracy = 0.6651
# Evaluating on validation set ...
# accuracy: 0.4379999976158142
# -------------------------------
# [8,    15] loss: 0.981,                             accuracy = 0.6557
# [8,    30] loss: 0.896,                             accuracy = 0.6917
# Evaluating on validation set ...
# accuracy: 0.4799999978542328
# -------------------------------
# [9,    15] loss: 1.074,                             accuracy = 0.6271
# [9,    30] loss: 0.920,                             accuracy = 0.6911
# Evaluating on validation set ...
# accuracy: 0.486
# -------------------------------
# [10,    15] loss: 0.873,                             accuracy = 0.6974
# [10,    30] loss: 0.804,                             accuracy = 0.7255
# Evaluating on validation set ...
# accuracy: 0.4959999971389771
# -------------------------------
# [11,    15] loss: 0.724,                             accuracy = 0.7536
# [11,    30] loss: 0.664,                             accuracy = 0.7766
# Evaluating on validation set ...
# accuracy: 0.5420000047683716
# -------------------------------
# [12,    15] loss: 0.612,                             accuracy = 0.7880
# [12,    30] loss: 0.567,                             accuracy = 0.7984
# Evaluating on validation set ...
# accuracy: 0.48400000619888306
# -------------------------------
# [13,    15] loss: 0.613,                             accuracy = 0.7823
# [13,    30] loss: 0.586,                             accuracy = 0.7937
# Evaluating on validation set ...
# accuracy: 0.4239999952316284
# -------------------------------
# [14,    15] loss: 0.707,                             accuracy = 0.7474
# [14,    30] loss: 0.621,                             accuracy = 0.7844
# Evaluating on validation set ...
# accuracy: 0.5520000052452088
# -------------------------------
# [15,    15] loss: 0.400,                             accuracy = 0.8734
# [15,    30] loss: 0.368,                             accuracy = 0.8755
# Evaluating on validation set ...
# accuracy: 0.5599999928474426
# -------------------------------
# [16,    15] loss: 0.278,                             accuracy = 0.9047
# [16,    30] loss: 0.250,                             accuracy = 0.9141
# Evaluating on validation set ...
# accuracy: 0.5579999990463257
# -------------------------------
# [17,    15] loss: 0.292,                             accuracy = 0.9146
# [17,    30] loss: 0.268,                             accuracy = 0.9052
# Evaluating on validation set ...
# accuracy: 0.5220000014305115
# -------------------------------
# [18,    15] loss: 0.364,                             accuracy = 0.8755
# [18,    30] loss: 0.281,                             accuracy = 0.8995
# Evaluating on validation set ...
# accuracy: 0.5159999957084656
# -------------------------------
# [19,    15] loss: 0.577,                             accuracy = 0.7964
# [19,    30] loss: 0.351,                             accuracy = 0.8750
# Evaluating on validation set ...
# accuracy: 0.5839999957084656
# -------------------------------
# [20,    15] loss: 0.243,                             accuracy = 0.9219
# [20,    30] loss: 0.166,                             accuracy = 0.9484
# Evaluating on validation set ...
# accuracy: 0.557999993801117
# -------------------------------
# Finished Training

# %%
# plots

xaxis = list(range(len(history['train_loss'])))
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
ax1.plot(xaxis, history['train_loss'])
ax1.set_title('Train Loss')
ax1.set_xlabel('Epoch Number')
ax1.set_ylabel('Loss')
ax2.plot(xaxis, history['train_acc'], label='Train')
ax2.plot(xaxis, history['val_acc'], label='Validation')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch Number')
ax2.set_ylabel('Accuracy')
ax2.legend()

# %% [markdown]
# ## Part B.2 (Finetuning feed-forward layers of pretrained model)

# %%
net = CustomNet(input_channels=3).to(DEVICE)
criterion = torch.nn.CrossEntropyLoss()

checkpoint = torch.load('4a.pth')
net.load_state_dict(checkpoint['model_state_dict'])
for param in net.parameters():
    param.requires_grad = False
net.fc1 = nn.Linear(512, 256)
net.fc2 = nn.Linear(256, 128)
net.fc3 = nn.Linear(128, 10)
net = net.to(DEVICE)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

tr = Trainer('4b2', net, optimizer, criterion,
             20, trainloader, valloader, log_every_iter=15, eval_every_epoch=1,
             device=DEVICE)
history = tr.train()
# Out:
# Number of iterations in each epoch: 40
# Number of validation iterations: 4
# Training started ...
# [1,    15] loss: 2.173,                             accuracy = 0.2354
# [1,    30] loss: 1.890,                             accuracy = 0.3422
# Evaluating on validation set ...
# accuracy: 0.3859999964237213
# -------------------------------
# [2,    15] loss: 1.616,                             accuracy = 0.4354
# [2,    30] loss: 1.554,                             accuracy = 0.4474
# Evaluating on validation set ...
# accuracy: 0.45600000524520873
# -------------------------------
# [3,    15] loss: 1.497,                             accuracy = 0.5010
# [3,    30] loss: 1.412,                             accuracy = 0.5182
# Evaluating on validation set ...
# accuracy: 0.4339999966621399
# -------------------------------
# [4,    15] loss: 1.390,                             accuracy = 0.5333
# [4,    30] loss: 1.370,                             accuracy = 0.5198
# Evaluating on validation set ...
# accuracy: 0.44800000262260437
# -------------------------------
# [5,    15] loss: 1.388,                             accuracy = 0.5276
# [5,    30] loss: 1.312,                             accuracy = 0.5526
# Evaluating on validation set ...
# accuracy: 0.4720000057220459
# -------------------------------
# [6,    15] loss: 1.249,                             accuracy = 0.5599
# [6,    30] loss: 1.230,                             accuracy = 0.5911
# Evaluating on validation set ...
# accuracy: 0.47399999904632567
# -------------------------------
# [7,    15] loss: 1.193,                             accuracy = 0.6042
# [7,    30] loss: 1.219,                             accuracy = 0.5859
# Evaluating on validation set ...
# accuracy: 0.44800000286102293
# -------------------------------
# [8,    15] loss: 1.216,                             accuracy = 0.5781
# [8,    30] loss: 1.155,                             accuracy = 0.6047
# Evaluating on validation set ...
# accuracy: 0.498000002861023
# -------------------------------
# [9,    15] loss: 1.128,                             accuracy = 0.6036
# [9,    30] loss: 1.100,                             accuracy = 0.6328
# Evaluating on validation set ...
# accuracy: 0.4940000038146973
# -------------------------------
# [10,    15] loss: 1.025,                             accuracy = 0.6568
# [10,    30] loss: 1.032,                             accuracy = 0.6490
# Evaluating on validation set ...
# accuracy: 0.4780000033378601
# -------------------------------
# [11,    15] loss: 1.017,                             accuracy = 0.6568
# [11,    30] loss: 0.997,                             accuracy = 0.6661
# Evaluating on validation set ...
# accuracy: 0.4959999995231628
# -------------------------------
# [12,    15] loss: 0.953,                             accuracy = 0.6719
# [12,    30] loss: 0.966,                             accuracy = 0.6729
# Evaluating on validation set ...
# accuracy: 0.47000000429153443
# -------------------------------
# [13,    15] loss: 0.901,                             accuracy = 0.6911
# [13,    30] loss: 0.929,                             accuracy = 0.6797
# Evaluating on validation set ...
# accuracy: 0.49200000619888307
# -------------------------------
# [14,    15] loss: 0.867,                             accuracy = 0.7125
# [14,    30] loss: 0.875,                             accuracy = 0.7031
# Evaluating on validation set ...
# accuracy: 0.46799999904632567
# -------------------------------
# [15,    15] loss: 0.809,                             accuracy = 0.7333
# [15,    30] loss: 0.792,                             accuracy = 0.7448
# Evaluating on validation set ...
# accuracy: 0.5040000033378601
# -------------------------------
# [16,    15] loss: 0.767,                             accuracy = 0.7432
# [16,    30] loss: 0.782,                             accuracy = 0.7380
# Evaluating on validation set ...
# accuracy: 0.4859999978542328
# -------------------------------
# [17,    15] loss: 0.746,                             accuracy = 0.7453
# [17,    30] loss: 0.695,                             accuracy = 0.7682
# Evaluating on validation set ...
# accuracy: 0.45599999284744264
# -------------------------------
# [18,    15] loss: 0.717,                             accuracy = 0.7615
# [18,    30] loss: 0.637,                             accuracy = 0.7969
# Evaluating on validation set ...
# accuracy: 0.47399999713897706
# -------------------------------
# [19,    15] loss: 0.749,                             accuracy = 0.7411
# [19,    30] loss: 0.673,                             accuracy = 0.7833
# Evaluating on validation set ...
# accuracy: 0.5019999938011169
# -------------------------------
# [20,    15] loss: 0.745,                             accuracy = 0.7328
# [20,    30] loss: 0.644,                             accuracy = 0.7891
# Evaluating on validation set ...
# accuracy: 0.47200000190734864
# -------------------------------
# Finished Training

# %%
# plots

xaxis = list(range(len(history['train_loss'])))
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
ax1.plot(xaxis, history['train_loss'])
ax1.set_title('Train Loss')
ax1.set_xlabel('Epoch Number')
ax1.set_ylabel('Loss')
ax2.plot(xaxis, history['train_acc'], label='Train')
ax2.plot(xaxis, history['val_acc'], label='Validation')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch Number')
ax2.set_ylabel('Accuracy')
ax2.legend()

# %% [markdown]
# ## Part B.3 (Finetuning the whole pretrained model)

# %%
net = CustomNet(input_channels=3).to(DEVICE)
criterion = torch.nn.CrossEntropyLoss()

checkpoint = torch.load('4a.pth')
net.load_state_dict(checkpoint['model_state_dict'])
net.fc1 = nn.Linear(512, 256)
net.fc2 = nn.Linear(256, 128)
net.fc3 = nn.Linear(128, 10)
net = net.to(DEVICE)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-4)

def accuracy_fn(outputs, y):
    preds = torch.argmax(outputs, axis=1)
    n = outputs.shape[0]
    return (preds == y).sum() / n

tr = Trainer('4b3', net, optimizer, criterion,
             20, trainloader, valloader, log_every_iter=15, eval_every_epoch=1,
             device=DEVICE)
history = tr.train()
# Out:
# Number of iterations in each epoch: 40
# Number of validation iterations: 4
# Training started ...
# [1,    15] loss: 2.292,                             accuracy = 0.1464
# [1,    30] loss: 2.252,                             accuracy = 0.2422
# Evaluating on validation set ...
# accuracy: 0.28600000095367434
# -------------------------------
# [2,    15] loss: 2.131,                             accuracy = 0.3245
# [2,    30] loss: 2.059,                             accuracy = 0.3005
# Evaluating on validation set ...
# accuracy: 0.3740000023841858
# -------------------------------
# [3,    15] loss: 1.909,                             accuracy = 0.3698
# [3,    30] loss: 1.799,                             accuracy = 0.4161
# Evaluating on validation set ...
# accuracy: 0.39399999952316284
# -------------------------------
# [4,    15] loss: 1.679,                             accuracy = 0.4573
# [4,    30] loss: 1.665,                             accuracy = 0.4646
# Evaluating on validation set ...
# accuracy: 0.4400000014305115
# -------------------------------
# [5,    15] loss: 1.525,                             accuracy = 0.5135
# [5,    30] loss: 1.514,                             accuracy = 0.4984
# Evaluating on validation set ...
# accuracy: 0.4880000057220459
# -------------------------------
# [6,    15] loss: 1.424,                             accuracy = 0.5281
# [6,    30] loss: 1.392,                             accuracy = 0.5406
# Evaluating on validation set ...
# accuracy: 0.525999993801117
# -------------------------------
# [7,    15] loss: 1.308,                             accuracy = 0.5672
# [7,    30] loss: 1.319,                             accuracy = 0.5625
# Evaluating on validation set ...
# accuracy: 0.5039999961853028
# -------------------------------
# [8,    15] loss: 1.229,                             accuracy = 0.5844
# [8,    30] loss: 1.245,                             accuracy = 0.5828
# Evaluating on validation set ...
# accuracy: 0.5199999985694885
# -------------------------------
# [9,    15] loss: 1.201,                             accuracy = 0.5974
# [9,    30] loss: 1.162,                             accuracy = 0.6062
# Evaluating on validation set ...
# accuracy: 0.5300000033378601
# -------------------------------
# [10,    15] loss: 1.146,                             accuracy = 0.6234
# [10,    30] loss: 1.115,                             accuracy = 0.6292
# Evaluating on validation set ...
# accuracy: 0.5419999985694886
# -------------------------------
# [11,    15] loss: 1.068,                             accuracy = 0.6312
# [11,    30] loss: 1.094,                             accuracy = 0.6432
# Evaluating on validation set ...
# accuracy: 0.5339999985694885
# -------------------------------
# [12,    15] loss: 1.019,                             accuracy = 0.6656
# [12,    30] loss: 1.016,                             accuracy = 0.6698
# Evaluating on validation set ...
# accuracy: 0.5419999985694886
# -------------------------------
# [13,    15] loss: 0.959,                             accuracy = 0.6854
# [13,    30] loss: 1.010,                             accuracy = 0.6641
# Evaluating on validation set ...
# accuracy: 0.5520000028610229
# -------------------------------
# [14,    15] loss: 0.955,                             accuracy = 0.6896
# [14,    30] loss: 0.906,                             accuracy = 0.7099
# Evaluating on validation set ...
# accuracy: 0.5659999980926513
# -------------------------------
# [15,    15] loss: 0.925,                             accuracy = 0.6943
# [15,    30] loss: 0.882,                             accuracy = 0.7167
# Evaluating on validation set ...
# accuracy: 0.5720000004768372
# -------------------------------
# [16,    15] loss: 0.839,                             accuracy = 0.7380
# [16,    30] loss: 0.850,                             accuracy = 0.7307
# Evaluating on validation set ...
# accuracy: 0.5700000004768372
# -------------------------------
# [17,    15] loss: 0.820,                             accuracy = 0.7380
# [17,    30] loss: 0.800,                             accuracy = 0.7406
# Evaluating on validation set ...
# accuracy: 0.5740000028610229
# -------------------------------
# [18,    15] loss: 0.771,                             accuracy = 0.7656
# [18,    30] loss: 0.779,                             accuracy = 0.7411
# Evaluating on validation set ...
# accuracy: 0.5820000052452088
# -------------------------------
# [19,    15] loss: 0.726,                             accuracy = 0.7771
# [19,    30] loss: 0.736,                             accuracy = 0.7693
# Evaluating on validation set ...
# accuracy: 0.577999993801117
# -------------------------------
# [20,    15] loss: 0.714,                             accuracy = 0.7693
# [20,    30] loss: 0.702,                             accuracy = 0.7818
# Evaluating on validation set ...
# accuracy: 0.5939999980926514
# -------------------------------
# Finished Training

# %%
# plots

xaxis = list(range(len(history['train_loss'])))
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(8, 4)
ax1.plot(xaxis, history['train_loss'])
ax1.set_title('Train Loss')
ax1.set_xlabel('Epoch Number')
ax1.set_ylabel('Loss')
ax2.plot(xaxis, history['train_acc'], label='Train')
ax2.plot(xaxis, history['val_acc'], label='Validation')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch Number')
ax2.set_ylabel('Accuracy')
ax2.legend()
